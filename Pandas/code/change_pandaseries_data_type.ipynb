# %%
# -*- coding: utf-8 -*-
# Indentation: Jupyter Notebook

'''
change data type of pandas
'''

__version__ = 1.0
__author__ = "Sourav Raj"
__author_email__ = "souravraj.iitbbs@gmail.com"

# %%
import pandas as pd

# %%
drinks = pd.read_csv("http://bit.ly/drinksbycountry")

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks.beer_servings = drinks.beer_servings.astype(float)

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.country.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-c8f2d58b8514> in <module>()
# ----> 1 drinks.country.astype(float)
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, raise_on_error, **kwargs)
#    3052         # else, only a single dtype is given
#    3053         new_data = self._data.astype(dtype=dtype, copy=copy,
# -> 3054                                      raise_on_error=raise_on_error, **kwargs)
#    3055         return self._constructor(new_data).__finalize__(self)
#    3056
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    3187
#    3188     def astype(self, dtype, **kwargs):
# -> 3189         return self.apply('astype', dtype=dtype, **kwargs)
#    3190
#    3191     def convert(self, **kwargs):
#
# ...

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %% [markdown]
# # change column datatype before reading csv

# %%
drinks = pd.read_csv("http://bit.ly/drinksbycountry", dtype = {'beer_serving': float })

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
orders = pd.read_table("C:/Users/sourav.raj.IN/Documents/PythonScripts/learn/orders.txt")

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
orders.item_price.str.replace("$", '').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-db4928d466d1> in <module>()
# ----> 1 orders.item_price.str.replace("$", '').mean()
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    5630                                       skipna=skipna)
#    5631         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 5632                             numeric_only=numeric_only)
#    5633
#    5634     return set_function_name(stat_func, name, cls)
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    2318                                           'numeric_only.'.format(name))
#    2319             with np.errstate(all='ignore'):
# ...

# %%
orders.item_price.str.replace("$", '').astype(float).mean()
# Out:
# 7.464335785374397

# %%
orders.item_name.str.contains('Chicken').head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: item_name, dtype: bool

# %%
orders.item_name.str.contains('Chicken').astype(int).head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: item_name, dtype: int32
