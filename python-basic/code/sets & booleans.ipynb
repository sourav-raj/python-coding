# %%
x = set()

# %%
x
# Out:
# set()

# %%
x.add(1)

# %%
x
# Out:
# {1}

# %%
x.add(2)

# %%
x
# Out:
# {1, 2}

# %%
x.add(1)

# %%
x
# Out:
# {1, 2}

# %%
l=[1,1,1,2,2,2,3,3,3,4]

# %%
l
# Out:
# [1, 1, 1, 2, 2, 2, 3, 3, 3, 4]

# %%
set(l)
# Out:
# {1, 2, 3, 4}

# %%
#booleans

# %%
a = True

# %%
1>2
# Out:
# False

# %%
11>2
# Out:
# True

# %%
b = None

# %%
b
