# %%
pwd
# Out:
# u'C:\\Users\\sourav.raj.IN\\Documents\\PythonScripts\\udemy'

# %%
f= open('test.txt')

# %%
f.read()
# Out:
# 'hello, everyone!'

# %%
f.read()
# Out:
# ''

# %%
f.seek(0)

# %%
f.read()
# Out:
# 'hello, everyone!'

# %%
f.seek(0)
f.readlines()
# Out:
# ['hello, everyone!']

# %%
# %%writefile new.txt
# First line
# Second line
# Out:
# Writing new.txt

# %%
for line in open('new.txt'):
    print line
# Out:
# First line
#
# Second line
